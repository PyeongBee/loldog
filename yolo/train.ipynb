# %%
from ultralytics import YOLO

# %%
# 학습할 모델 로드
model = YOLO('best_0126.pt')

# %%
import torch
print(torch.cuda.is_available(), torch.cuda.device_count())
print(torch.cuda.get_device_name(0))
# Out:
# True 1
# NVIDIA GeForce RTX 2060 SUPER

# %%
# train
results = model.train(data="../dataset/data.yaml", imgsz=640, epochs=300, device="0")
# Out:
# Ultralytics 8.4.7  Python-3.12.10 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 2060 SUPER, 8192MiB)
# ...

# %%
# tflite 변환 (colab에서 실행)
best_model = YOLO("runs/detect/train2/weights/best.pt")
# path = best_model.export(format="tflite", imgsz=640)

# %%
# model test
# best_model = YOLO("runs/detect/train/weights/best.pt")
# tflite_model = YOLO("runs/detect/train/weights/after_train_leesin_11n_best.tflite")
results = best_model.predict(source="../dataset/test/images", save=True)
# Out:
# image 1/1 c:\workspace\projects\loldog\yolo\..\dataset\test\images\lol_jg_leesin (10).png: 640x640 1 Leesin, 10.3ms
# Speed: 3.6ms preprocess, 10.3ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\workspace\projects\loldog\yolo\runs\detect\predict
