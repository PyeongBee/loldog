# %%
from ultralytics import YOLO

# %%
# YOLO26 나노(Nano) 모델 로드
model = YOLO('yolo11n.pt')

# %%
import torch
print(torch.cuda.is_available(), torch.cuda.device_count())
print(torch.cuda.get_device_name(0))
# Out:
# False 0
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[33], line 3
#       1 import torch
#       2 print(torch.cuda.is_available(), torch.cuda.device_count())
# ----> 3 print(torch.cuda.get_device_name(0))
#
# File ~\AppData\Roaming\Python\Python313\site-packages\torch\cuda\__init__.py:582, in get_device_name(device)
#     570 def get_device_name(device: "Device" = None) -> str:
#     571     r"""Get the name of a device.
#     572
#     573     Args:
#    (...)    580         str: the name of the device
#     581     """
# --> 582     return get_device_properties(device).name
#
# File ~\AppData\Roaming\Python\Python313\site-packages\torch\cuda\__init__.py:614, in get_device_properties(device)
#     602 def get_device_properties(device: "Device" = None) -> _CudaDeviceProperties:
#     603     r"""Get the properties of a device.
#     604
#     605     Args:
#    (...)    612         _CudaDeviceProperties: the properties of the device
#     613     """
# --> 614     _lazy_init()  # will define _get_device_properties
#     615     device = _get_device_index(device, optional=True)
#     616     if device < 0 or device >= device_count():
#
# File ~\AppData\Roaming\Python\Python313\site-packages\torch\cuda\__init__.py:403, in _lazy_init()
#     398     raise RuntimeError(
#     399         "Cannot re-initialize CUDA in forked subprocess. To use CUDA with "
#     400         "multiprocessing, you must use the 'spawn' start method"
#     401     )
#     402 if not hasattr(torch._C, "_cuda_getDeviceCount"):
# --> 403     raise AssertionError("Torch not compiled with CUDA enabled")
#     404 if _cudart is None:
#     405     raise AssertionError(
#     406         "libcudart functions unavailable. It looks like you have a broken build?"
#     407     )
#
# AssertionError: Torch not compiled with CUDA enabled

# %%
results = model.train(data="../dataset/data.yaml", imgsz=1858, epochs=50)
# Out:
# New https://pypi.org/project/ultralytics/8.4.7 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.252  Python-3.13.3 torch-2.9.1+cpu CPU (Intel Core i5-9600K 3.70GHz)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=../dataset/data.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=1858, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\workspace\projects\loldog\yolo\runs\detect\train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    430867  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,590,035 parameters, 2,590,019 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# WARNING imgsz=[1858] must be multiple of max stride 32, updating to [1888]
# train: Fast image access  (ping: 0.00.0 ms, read: 2487.8260.9 MB/s, size: 7748.4 KB)
# train: Scanning C:\workspace\projects\loldog\dataset\train\labels.cache... 7 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 7/7 3.3Mit/s 0.0s
# val: Fast image access  (ping: 0.00.0 ms, read: 2082.196.4 MB/s, size: 7317.9 KB)
# val: Scanning C:\workspace\projects\loldog\dataset\valid\labels.cache... 2 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2/2 838.9Kit/s 0.0s
# Plotting labels to C:\workspace\projects\loldog\yolo\runs\detect\train\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 1888 train, 1888 val
# Using 0 dataloader workers
# Logging results to C:\workspace\projects\loldog\yolo\runs\detect\train
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50         0G      1.182      11.95      1.516         10       1888: 100% ━━━━━━━━━━━━ 1/1 17.7s/it 17.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.2s/it 2.2s
#                    all          2          2    0.00333          1    0.00554    0.00184
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50         0G      1.206      12.12      1.498          9       1888: 100% ━━━━━━━━━━━━ 1/1 16.5s/it 16.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.7s/it 2.7s
#                    all          2          2    0.00333          1    0.00512    0.00235
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50         0G      1.402      20.92      1.387          5       1888: 100% ━━━━━━━━━━━━ 1/1 16.6s/it 16.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.3s/it 2.3s
#                    all          2          2    0.00333          1    0.00546    0.00365
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50         0G      1.039      10.16      1.356         10       1888: 100% ━━━━━━━━━━━━ 1/1 16.8s/it 16.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.1s/it 2.1s
#                    all          2          2    0.00333          1     0.0046    0.00352
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50         0G     0.9076      8.016      1.244         13       1888: 100% ━━━━━━━━━━━━ 1/1 16.8s/it 16.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.1s/it 2.1s
#                    all          2          2    0.00333          1     0.0116    0.00911
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50         0G     0.9922       10.4      1.364         11       1888: 100% ━━━━━━━━━━━━ 1/1 16.2s/it 16.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.1s/it 2.1s
#                    all          2          2    0.00333          1     0.0302     0.0205
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50         0G     0.6528       9.93      1.115         10       1888: 100% ━━━━━━━━━━━━ 1/1 16.4s/it 16.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.4s/it 2.4s
#                    all          2          2    0.00333          1     0.0285     0.0234
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50         0G     0.8418      8.571      1.102         11       1888: 100% ━━━━━━━━━━━━ 1/1 16.0s/it 16.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.2s/it 2.2s
#                    all          2          2    0.00333          1      0.161     0.0381
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50         0G     0.8109      11.16      1.071          9       1888: 100% ━━━━━━━━━━━━ 1/1 16.1s/it 16.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.1s/it 2.1s
#                    all          2          2    0.00333          1      0.105     0.0659
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50         0G     0.9556      7.683      1.081         15       1888: 100% ━━━━━━━━━━━━ 1/1 16.0s/it 16.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.1s/it 2.1s
#                    all          2          2    0.00333          1     0.0995     0.0747
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50         0G     0.7625      12.94       1.01          7       1888: 100% ━━━━━━━━━━━━ 1/1 16.0s/it 16.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.0s/it 2.0s
#                    all          2          2    0.00333          1      0.153      0.115
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50         0
Hz)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.9s/it 1.9s
#                    all          2          2      0.518          1      0.995      0.945
# Speed: 12.6ms preprocess, 563.7ms inference, 0.0ms loss, 284.8ms postprocess per image
# Results saved to C:\workspace\projects\loldog\yolo\runs\detect\train

# %%
best_model = YOLO("runs/detect/train/weights/best.pt")
path = best_model.export(format="onnx", imgsz=640, opset=12)
# Out:
# Ultralytics 8.4.7  Python-3.12.10 torch-2.5.1+cu121 CPU (Intel Core i5-9600K 3.70GHz)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from 'runs\detect\train\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 5, 8400) (5.6 MB)
# requirements: Ultralytics requirements ['onnxslim>=0.1.71', 'onnxruntime-gpu'] not found, attempting AutoUpdate...
# Collecting onnxslim>=0.1.71
#   Downloading onnxslim-0.1.82-py3-none-any.whl.metadata (10 kB)
# Collecting onnxruntime-gpu
#   Downloading onnxruntime_gpu-1.23.2-cp312-cp312-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: colorama in c:\workspace\projects\loldog\.venv312\lib\site-packages (from onnxslim>=0.1.71) (0.4.6)
# Requirement already satisfied: ml-dtypes in c:\workspace\projects\loldog\.venv312\lib\site-packages (from onnxslim>=0.1.71) (0.5.4)
# Requirement already satisfied: onnx in c:\workspace\projects\loldog\.venv312\lib\site-packages (from onnxslim>=0.1.71) (1.20.1)
# Requirement already satisfied: packaging in c:\workspace\projects\loldog\.venv312\lib\site-packages (from onnxslim>=0.1.71) (26.0)
# Requirement already satisfied: sympy>=1.13.1 in c:\workspace\projects\loldog\.venv312\lib\site-packages (from onnxslim>=0.1.71) (1.13.1)
# Requirement already satisfied: coloredlogs in c:\workspace\projects\loldog\.venv312\lib\site-packages (from onnxruntime-gpu) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\workspace\projects\loldog\.venv312\lib\site-packages (from onnxruntime-gpu) (25.12.19)
# Requirement already satisfied: numpy>=1.21.6 in c:\workspace\projects\loldog\.venv312\lib\site-packages (from onnxruntime-gpu) (2.4.1)
# Requirement already satisfied: protobuf in c:\workspace\projects\loldog\.venv312\lib\site-packages (from onnxruntime-gpu) (6.33.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\workspace\projects\loldog\.venv312\lib\site-packages (from sympy>=1.13.1->onnxslim>=0.1.71) (1.3.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\workspace\projects\loldog\.venv312\lib\site-packages (from coloredlogs->onnxruntime-gpu) (10.0)
# Requirement already satisfied: typing_extensions>=4.7.1 in c:\workspace\projects\loldog\.venv312\lib\site-packages (from onnx->onnxslim>=0.1.71) (4.15.0)
# Requirement already satisfied: pyreadline3 in c:\workspace\projects\loldog\.venv312\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime-gpu) (3.5.4)
# Downloading onnxslim-0.1.82-py3-none-any.whl (167 kB)
# Downloading onnxruntime_gpu-1.23.2-cp312-cp312-win_amd64.whl (244.5 MB)
#    ---------------------------------------- 0.0/244.5 MB ? eta -:--:--
#    -- ------------------------------------- 12.6/244.5 MB 60.7 MB/s eta 0:00:04
#    ---- ----------------------------------- 25.2/244.5 MB 61.2 MB/s eta 0:00:04
#    ------ --------------------------------- 37.7/244.5 MB 61.5 MB/s eta 0:00:04
#    -------- ------------------------------- 50.6/244.5 MB 61.9 MB/s eta 0:00:04
#    ---------- ----------------------------- 63.2/244.5 MB 61.9 MB/s eta 0:00:03
#    ------------ --------------------------- 76.3/244.5 MB 62.4 MB/s eta 0:00:03
#    -------------- ------------------------- 88.9/244.5 MB 62.3 MB/s eta 0:00:03
#    ---------------- ----------------------- 98.6/244.5 MB 60.5 MB/s eta 0:00:03
#    ----------------- --------------------- 111.9/244.5 MB 60.6 MB/s eta 0:00:03
#    ------------------- ------------------- 125.0/244.5 MB 61.0 MB/s eta 0:00:02
#    --------------------- ----------------- 132.9/244.5 MB 58.5 MB/s eta 0:00:02
#    ----------------------- --------------- 146.3/244.5 MB 59.1 MB/s eta 0:00:02
#    ------------------------ -------------- 155.2/244.5 MB 58.3 MB/s eta 0:00:02
#    -------------------------- ------------ 165.2/244.5 MB 57.0 MB/s eta 0:00:02
#    ---------------------------- ---------- 177.7/244.5 MB 57.4 MB/s eta 0:00:02
#    ------------------------------ -------- 189.8/244.5 MB 57.5 MB/s eta 0:00:01
#    ------------------------------- ------- 195.6/244.5 MB 55.5 MB/s eta 0:00:01
#    --------------------------------- ----- 208.7/244.5 MB 56.0 MB/s eta 0:00:01
#    ----------------------------------- --- 221.5/244.5 MB 56.2 MB/s eta 0:00:01
#    ------------------------------------- - 233.6/244.5 MB 56.3 MB/s eta 0:00:01
#    --------------------------------------- 244.5/244.5 MB 56.6 MB/s eta 0:00:00
# Installing collected packages: onnxslim, onnxruntime-gpu
# Successfully installed onnxruntime-gpu-1.23.2 onnxslim-0.1.82
#
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
#
# requirements: AutoUpdate success  14.4s
# WARNING requirements: Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.20.1 opset 12...
# ONNX: slimming with onnxslim 0.1.82...
# ONNX: export success  16.2s, saved as 'runs\detect\train\weights\best.onnx' (10.1 MB)
#
# Export complete (16.6s)
# Results saved to C:\workspace\projects\loldog\yolo\runs\detect\train\weights
# Predict:         yolo predict task=detect model=runs\detect\train\weights\best.onnx imgsz=640
# Validate:        yolo val task=detect model=runs\detect\train\weights\best.onnx imgsz=640 data=../dataset/data.yaml
# Visualize:       https://netron.app
